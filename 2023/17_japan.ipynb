# %%
# ライブラリの再読み込み用
# このノートを実行後、ライブラリのインポートから再実行する
import importlib
import fastf1lib
importlib.reload(fastf1lib)
# Out:
# <module 'fastf1lib' from '/work/fastf1-work/2023/../libs/fastf1lib.py'>

# %%
import sys
import importlib
sys.path.append("../libs")
from fastf1lib import myFastf1
importlib.reload(sys.modules["fastf1lib"])

ff1 = myFastf1()

# %%
session_race = ff1.load_session_o("japan", 2023, 'R')
# Out:
# core           INFO 	Loading data for Japanese Grand Prix - Race [v3.1.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '81', '16', '44', '55', '63', '14', '31', '10', '40', '22', '24', '27', '20', '23', '2', '18', '11', '77']

# %%
session_qual = ff1.load_session_o("japan", 2023, 'Q')
# Out:
# core           INFO 	Loading data for Japanese Grand Prix - Qualifying [v3.1.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '81', '4', '16', '11', '55', '44', '63', '22', '14', '40', '10', '23', '31', '20', '77', '18', '27', '24', '2']

# %%
ff1.tyre_strategies(session_race)

# %%
ff1.position_changes(session_race)

# %%
ff1.quali_result(session_qual)

# %%
ff1.driver_laptime('ALO', session_race)
ff1.driver_laptime('OCO', session_race)
ff1.driver_laptime('GAS', session_race)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
ff1.laptime_distribution(session_race)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
ff1.speed_traces(session_qual)

# %%
ff1.speed_compare('VER', 'PIA',session_qual)

# %%
ff1.team_comparison(session_race)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import fastf1
import pandas as pd

fastf1.Cache.enable_cache('../../fastf1/cache')
session = fastf1.get_session(2023, 'japan', 'q')
session.load()
# Out:
# core           INFO 	Loading data for Japanese Grand Prix - Qualifying [v3.1.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '81', '4', '16', '11', '55', '44', '63', '22', '14', '40', '10', '23', '31', '20', '77', '18', '27', '24', '2']
# VER
# PIA
# NOR
# LEC
# PER
# SAI
# HAM
# RUS
# TSU
# ALO
# LAW
# GAS
# ALB
# ...

# %%
import math
import numpy as np

drivers = pd.unique(session.laps['Driver'])
for drv in drivers:
    drv_fastest_lap = session.laps.pick_driver(drv).pick_fastest()
    #if math.isnan(drv_fastest_lap['Driver']):
    #print(drv_fastest_lap['Driver'])
    if not drv_fastest_lap['Driver'] is np.nan:
        print(drv_fastest_lap['Driver'])
# Out:
# VER
# PIA
# NOR
# LEC
# PER
# SAI
# HAM
# RUS
# TSU
# ALO
# LAW
# GAS
# ALB
# OCO
# MAG
# BOT
# STR
# HUL
# ZHO
